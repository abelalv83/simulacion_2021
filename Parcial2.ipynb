# %% [markdown]
# # Parcial 2
# (Fecha de entrega Viernes 15 a las 12 p.m. )
# ## Punto 1
# Usted debera entregar una progrmación en Phyton orientada a objetos, con los siguientes códigos
# *  Euler explicito
# *  Euler implicito
# *  Trapecio
# *  Runge Kutta de 4 de pasos y 4 orden explicito
# *  Runge Kutta implicito de 2 pasos 4 orden, el cual se presenta en el siguiente gráfico
#
# ![rk2-4.JPG](data:image/jpeg;base64,...)
# *   Método que cáclula el orden ce convergencia para cada uno de los métodos $C,P$
#
# *   Análisis de convergencia numerica.

# %% [markdown]
# ## punto 2
#
# Sea el método
#
# $$U^{n+1}=U^n+\Delta t\Big((1-\theta)f(U^n,t_n)+\theta f(U^{n+1},t_{n+1})\Big)$$
#
# para $\theta\in[0,1]$.
#
# encuentre el valor de $\theta$, para que el método tenga mayor orden de convergencia.
