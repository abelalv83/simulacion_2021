# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# %cd gdrive/MyDrive/Github/Simulacion1/
# !ls
# Out:
# /content/gdrive/MyDrive/Github/Simulacion1
# clase.py	      Dimensional.ipynb  main.ipynb
# compartimental.ipynb  Figuras		 __pycache__

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import importlib
import clase
importlib.reload(clase)

## Definición de funcion de la ecuacion de la forma 
def f(u,t):
    return 10*u


imputs={"a":0.0,
        "b":1.0,
        "N":30,
        "u0":1.0}

df=clase.aprox_ODE(imputs)
df.Euler(f)
df.grafica()
